# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
with open("dataout.csv",'w') as data_out: 

 with open("statistics (1).txt",'r') as data_file:

    for line in data_file:
        data= line.strip().split("&")
        print(int(data[1]))
#         for a in data:
#             data1= a.split(">,")
#             print(int(data1[1]))
#             data_out.write(data[1]+ "," +data[2] + "\n")
#             for b in data1:
#                 data2= b.split(">")

#                 print(int(data2[1]))
    
#             if (int(data2[1]))>2:
              # print(int(data1[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-61a197030edd> in <module>
#       5     for line in data_file:
#       6         data= line.strip().split("&")
# ----> 7         print(int(data[1]))
#       8 #         for a in data:
#       9 #             data1= a.split(">,")
#
# ValueError: invalid literal for int() with base 10: 'label'

# %%
import pandas as pd

# DataFrame of each student and the votes they get
dataframe = pd.read_csv('statistics (1).txt' , sep = '&')
dataframe.head()
dataframe.info()
#  pd.to_numeric(df["a"])
# dataframe=pd.to_numeric(dataframe['frequency'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   predicate  90 non-null     object
#  1   label      90 non-null     object
#  2   frequency  90 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %%
len(dataframe)
# Out:
# 90

# %%
# df1 = dataframe['label','frequency']
del dataframe["label"]
dataframe.head()
df= dataframe

# %%
df.dtypes

# df1 = df.head(10)
# df1
df1 = df.iloc[30:40]

# %%
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='predicate', y='frequency', figsize=(6, 6), title="Top 10 frequent Predicates", colormap=None, rot=None,fontsize='15')
print("hi")
# ax.figure.savefig('demo-file.png')
# plot.title("Death rate if corona virus")
# plt.show()
# df.plot.bar(x='names', y='val', rot=0, figsize=(15, 10))
# f = ax.figure()
# f.set_figwidth(10)
# f.set_figheight(10)
# f.savefig('subjectslabels.png')
# Out:
# hi

# %%
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='label', y='frequency', figsize=(4, 6), title="Top 10 frequent Subjects", colormap=None)
print("hi")

# %%
import pandas as pd

dataframe = pd.read_csv('statistics (1).txt' , sep = '&')
dataframe.head()
dataframe.info()
del dataframe["label"]
dataframe.head()
df= dataframe
df1 = df.head(10)
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='predicate', y='frequency', figsize=(6, 6), title="Top 10 frequent Predicates", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   predicate  100 non-null    object
#  1   label      100 non-null    object
#  2   frequency  100 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB
# hi

# %%
import pandas as pd

dataframe = pd.read_csv('sub-stat.txt' , sep = '&')
dataframe.head()
del dataframe["subject"]
dataframe.head()
df= dataframe
df1 = df.head(10)
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='Subject label', y='frequency', figsize=(6, 6), title="Top 10 frequent Subjects", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# hi

# %%
import pandas as pd

dataframe = pd.read_csv('object.txt' , sep = '&')
dataframe.head()
del dataframe["object"]
dataframe.head()
df= dataframe
df1 = df.head(10)
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='Object label', y='frequency', figsize=(7, 6), title="Top 10 frequent Objects", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# hi

# %%
import pandas as pd

dataframe = pd.read_csv('rdf-types.txt' , sep = '&')
dataframe.head()
del dataframe["rdftype"]
dataframe.head()
df= dataframe
df1 = df.head(10)
import matplotlib.pyplot as plt
ax = df1.plot.barh(x='Type label', y='frequency', figsize=(7, 6), title=" frequent RDF types", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# hi

# %%
import pandas as pd

dataframe = pd.read_csv('Datatype.txt' , sep = '&')
dataframe.head()
# del dataframe["label"]
dataframe.head()
# Out:
#      boogh    frequency
# 0  Boolean         2657
# 1  Integer         2657
# 2   String         1477
# 3   Double           11
# 4  Decimal           11

# %%
df= dataframe
# df1 = df.head(10)
import matplotlib.pyplot as plt
ax = df.plot.barh(x='boogh', y='frequency', figsize=(7, 6), title="Frequency of Data types", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'boogh'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-89f83c2599fa> in <module>
#       2 # df1 = df.head(10)
# ...

# %%
data= {
  "Datatype": ['Boolean' , 'Integer', 'String' , 'Double', 'Decimal','LangString' , 'SpecialDatatype'],
  "frequency": [2657, 2657,1477, 11, 11, 7, 5]
}
df=pd.DataFrame(data)
df
# Out:
#           Datatype frequency
# 0          Boolean      2657
# 1          Integer      2657
# 2           String      1477
# 3           Double        11
# 4          Decimal        11
# 5       LangString         7
# 6  SpecialDatatype         5

# %%
ax = df.plot.barh(x='Data_type', y='frequency', figsize=(7, 6), title="Frequency of Data types", colormap=None, rot=None,fontsize='15')
print("hi")
# Out:
# hi

# %%
df.groupby(['Datatype']).sum().plot(kind='pie', y='frequency', figsize=(5, 10))
# Out:
# <AxesSubplot:ylabel='frequency'>

# %%
# !import wordcloud
# Out:
# zsh:1: command not found: import

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
df= pd.read_csv('Datatype.txt' , sep = '&')
wordcloud = WordCloud().generate_from_frequencies(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-acd2310a9885> in <module>
#       1 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#       2 df= pd.read_csv('Datatype.txt' , sep = '&')
# ----> 3 wordcloud = WordCloud().generate_from_frequencies(df)
#
# /opt/conda/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     406         """
#     407         # make sure frequencies are sorted and normalized
# --> 408         frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409         if len(frequencies) <= 0:
#     410             raise ValueError("We need at least 1 word to plot a word cloud, "
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ...

# %%
dataframe = pd.read_csv('rdf-types.txt' , sep = '&')
df= dataframe.head(10)
df
# Out:
#                                              rdftype            Type label  \
# 0     <http://bio2rdf.org/drugbank_vocabulary:Drug>                  Drug
# 1  <http://bio2rdf.org/pharmgkb_vocabulary:Variat...   PharmGKB Variation
# 2                <http://xmlns.com/foaf/0.1/Person>                Person
# 3  <http://bio2rdf.org/drugbank_vocabulary:Small-...       Small molecule
# 4                      <http://bio2rdf.org/mi:0326>               protein
# 5  <http://bio2rdf.org/clinicaltrials_vocabulary:...             Location
# 6  <http://bio2rdf.org/clinicaltrials_vocabulary:...       Clinical Study
# 7  <http://bio2rdf.org/drugbank_vocabulary:Biotech>               Biotech
# 8    <http://bio2rdf.org/omim_vocabulary:Phenotype>             phenotype
# 9         <http://bio2rdf.org/omim_vocabulary:Gene>                  gene
#
#    frequency
# 0       8407
# 1       7797
# 2        997
# 3        925
# 4        916
# 5        885
# 6        731
# 7        717
# 8        615
# ...

# %%
data= {
  "Datatype": ['Boolean' , 'Integer', 'String' , 'Double', 'Decimal','LangString' , 'SpecialDatatype'],
  "frequency": [2657, 2657,1477, 11, 11, 7, 5]
}
df=pd.DataFrame(data)
df
# Out:
#           Datatype  frequency
# 0          Boolean       2657
# 1          Integer       2657
# 2           String       1477
# 3           Double         11
# 4          Decimal         11
# 5       LangString          7
# 6  SpecialDatatype          5

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# create word cloud
wc = WordCloud(max_font_size=65, max_words=100, background_color="white")
wc.generate_from_frequencies(df.set_index('Datatype')['frequency'])

# plot
plt.figure()
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
